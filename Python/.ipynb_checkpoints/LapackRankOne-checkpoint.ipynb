# %%
import scipy.linalg.lapack
slaed9 = scipy.linalg.lapack.flapack.slaed9
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-c105ac06053a> in <module>
#       1 import scipy.linalg.lapack
# ----> 2 slaed9 = scipy.linalg.lapack.flapack.slaed9
#
# /usr/lib/python3/dist-packages/scipy/_lib/_util.py in __getattr__(self, name)
#     168                       % (self._old_name, self._new_name),
#     169                       DeprecationWarning)
# --> 170         return getattr(self._mod, name)
#     171
#     172
#
# AttributeError: module 'scipy.linalg.lapack' has no attribute 'slaed9'

# %%
import numpy as np

# %%
dir(scipy.linalg.lapack)
# Out:
# ['_DeprecatedImport',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_clapack',
#  '_compute_lwork',
#  '_dep_message',
#  '_flapack',
#  '_get_funcs',
#  '_lapack_alias',
#  '_np',
#  'absolute_import',
#  'cgbsv',
#  'cgbtrf',
#  'cgbtrs',
#  'cgebal',
#  'cgecon',
#  'cgees',
#  'cgeev',
#  'cgeev_lwork',
#  'cgegv',
#  'cgehrd',
#  'cgehrd_lwork',
#  'cgels',
#  'cgels_lwork',
#  'cgelsd',
#  'cgelsd_lwork',
#  'cgelss',
#  'cgelss_lwork',
#  'cgelsy',
#  'cgelsy_lwork',
#  'cgeqp3',
#  'cgeqrf',
#  'cgerqf',
#  'cgesdd',
#  'cgesdd_lwork',
#  'cgesv',
#  'cgesvd',
#  'cgesvd_lwork',
#  'cgesvx',
#  'cgetrf',
#  'cgetri',
#  'cgetri_lwork',
#  'cgetrs',
#  'cgges',
#  'cggev',
#  'cgglse',
#  'cgglse_lwork',
#  'cgtsv',
#  'chbevd',
#  'chbevx',
#  'checon',
#  'cheev',
#  'cheevd',
#  'cheevr',
#  'chegst',
#  'chegv',
#  'chegvd',
#  'chegvx',
#  'chesv',
#  'chesv_lwork',
# ...
